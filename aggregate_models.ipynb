# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nn = pd.read_csv('neural_net1.csv', index_col=0)
rf = pd.read_csv('random_forest1.csv', index_col=0)
train = pd.read_csv('train.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)

# %%
sum(train.y)
# Out:
# 211455

# %%
s = 0
for i in nn['Predicted']:
    if i >= 0.5:
        s += 1
s
# Out:
# 522

# %%
s = 0
for i in rf['Predicted']:
    if i >= 0.5:
        s += 1
s
# Out:
# 35334

# %%
nn['Predicted'] = (nn['Predicted'] + rf['Predicted']) / 2

# %%
s = 0
for i in nn['Predicted']:
    if i >= 0.5:
        s += 1
s
# Out:
# 13260

# %%
nn[['Predicted']].to_csv('submission_agg.csv')

# %%
rf
# Out:
#         Predicted
# id
# 592380   0.468750
# 592381   0.218750
# 592382   0.489583
# 592383   0.484375
# 592384   0.273438
# 592385   0.390625
# 592386   0.453125
# 592387   0.421875
# 592388   0.519531
# 592389   0.296875
# 592390   0.343750
# 592391   0.453125
# 592392   0.523438
# 592393   0.468750
# 592394   0.370833
# 592395   0.507812
# 592396   0.562500
# 592397   0.359375
# 592398   0.312500
# 592399   0.671875
# 592400   0.203125
# 592401   0.204427
# 592402   0.578125
# 592403   0.421875
# 592404   0.359375
# 592405   0.445312
# 592406   0.265625
# 592407   0.562500
# 592408   0.269531
# 592409   0.361979
# ...           ...
# 784209   0.531250
# 784210   0.750000
# 784211   0.414062
# 784212   0.316890
# 784213   0.453125
# 784214   0.312500
# 784215   0.437500
# 784216   0.515625
# 784217   0.250000
# 784218   0.640625
# 784219   0.406250
# 784220   0.437500
# 784221   0.343750
# 784222   0.460938
# 784223   0.375000
# 784224   0.546875
# 784225   0.343750
# ...
